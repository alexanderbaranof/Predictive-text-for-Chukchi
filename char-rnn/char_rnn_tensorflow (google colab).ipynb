# %%
# !git clone https://github.com/sherjilozair/char-rnn-tensorflow.git
# Out:
# Cloning into 'char-rnn-tensorflow'...
# remote: Enumerating objects: 404, done.
# remote: Total 404 (delta 0), reused 0 (delta 0), pack-reused 404
# Receiving objects: 100% (404/404), 508.45 KiB | 14.95 MiB/s, done.
# Resolving deltas: 100% (238/238), done.

# %%
# !ls
# Out:
# sample_data

# %%
# %cd char-rnn-tensorflow
# Out:
# /content/char-rnn-tensorflow

# %%
# !ls
# Out:
# data	    logs      __pycache__  sample.py  train.py
# LICENSE.md  model.py  README.md    save       utils.py

# %%
# !pip install tensorflow==1.13.0rc1
# Out:
# ...
#      |████████████████████████████████| 92.7MB 45kB/s
# ...
#      |████████████████████████████████| 51kB 7.9MB/s
# ...
#      |████████████████████████████████| 368kB 53.7MB/s
# ...
#      |████████████████████████████████| 3.1MB 35.2MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
# !python train.py --data_dir data/chukci/ --model lstm --rnn_size 32 --num_layers 2 --num_epochs 25 --seq_length 64
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 3959/8950 (epoch 11), train_loss = 1.927, time/batch = 0.041
# 3960/8950 (epoch 11), train_loss = 2.010, time/batch = 0.036
# 3961/8950 (epoch 11), train_loss = 1.937, time/batch = 0.036
# 3962/8950 (epoch 11), train_loss = 1.934, time/batch = 0.035
# 3963/8950 (epoch 11), train_loss = 1.978, time/batch = 0.034
# 3964/8950 (epoch 11), train_loss = 1.982, time/batch = 0.036
# 3965/8950 (epoch 11), train_loss = 1.927, time/batch = 0.034
# 3966/8950 (epoch 11), train_loss = 2.011, time/batch = 0.038
# 3967/8950 (epoch 11), train_loss = 1.965, time/batch = 0.042
# 3968/8950 (epoch 11), train_loss = 1.973, time/batch = 0.034
# 3969/8950 (epoch 11), train_loss = 1.961, time/batch = 0.035
# 3970/8950 (epoch 11), train_loss = 1.949, time/batch = 0.033
# 3971/8950 (epoch 11), train_loss = 1.969, time/batch = 0.034
# 3972/8950 (epoch 11), train_loss = 1.994, time/batch = 0.038
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cp -r ./save/ /content/drive/MyDrive/Chukci/lstm_32/
